# %% [markdown]
# <a href="https://colab.research.google.com/github/Tachelgup/Python_base/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input('a:'))
b = int(input('b:'))
c = int(input('c:'))
y = (a*(a-b)+2*a*b)/((a+b)*c)
print('y =',y)
# Out:
# a:2
# b:3
# c:1
# y = 2.0

# %%
from math import log, pow
x = int(input('x:'))
z = x*pow(log(x),2)+x/(log(x)-1)
print('z =', z)
# Out:
# x:3
# z = 34.0430188096792

# %%
from math import pow, pi
r = int(input('r:'))
l = 2*pi*r
s = pi*pow(r,2)
print("l =", l)
print('s =', s)
# Out:
# r:1
# l = 6.283185307179586
# s = 3.141592653589793

# %%
n = int(input('seconds: '))
while n>=3600:
  n-=3600
print('minutes:', n//60)
# Out:
# seconds: 3789
# minutes: 3

# %%
a = int(input('a: '))
b = int(input('b: '))
print('same parity:', a%2 == b%2)
# Out:
# a: 3
# b: 4
# same parity: False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import log, pow
x = int(input('x:'))
if x > 0:
  f = log(x) + 9
else:
  f = -x/(pow(x,2)-7)
print('f=',f)
# Out:
# x:3
# f= 10.09861228866811

# %%
from math import sqrt
a1 = int(input('a1:'))
b1 = int(input('b1:'))
c1 = int(input('c1:'))
a2 = int(input('a2:'))
b2 = int(input('b2:'))
c2 = int(input('c2:'))

p1 = (a1+b1+c1)/2
p2 = (a2+b2+c2)/2

print('equally large: ',sqrt(p1*(p1-a1)*(p1-b1)*(p1-c1)) == sqrt(p2*(p2-a2)*(p2-b2)*(p2-c2)))
# Out:
# a1:1
# b1:2
# c1:3
# a2:2
# b2:3
# c2:1
# equally large:  True

# %%
# a >= b >= c
a = int(input('a:'))
b = int(input('b:'))
c = int(input('c:'))

if a < b:
    a, b = b, a
if a < c:
    a, c = c, a
if b < c:
    b, c = c, b

print(f"a = {a}, b = {b}, c = {c}")
# Out:
# a:1
# b:3
# c:2
# a = 3, b = 2, c = 1

# %%
b = int(input('b: '))
while 10 > b or b > 99:
  b = int(input('b: '))
s = b % 10 + b // 10
print(f'the sum of the digits is a multiple of three: {s%3 == 0}')
a = int(input('a: '))
print(f'the sum of the digits is a multiple of a: {s%a == 0}')
# Out:
# b: 1
# b: 2
# b: 3
# b: 5
# b: 231
# b: 54
# the sum of the digits is a multiple of three: True
# a: 4
# the sum of the digits is a multiple of a: False

# %%
a = int(input('a:'))
b = int(input('b:'))
c = int(input('c:'))
d = int(input('d:'))
e = int(input('e:'))
f = int(input('f:'))

#a
if (abs(a-e) == abs(b-f)) & (e != c) & (f != d):
  print('Yes')
else: print('No')

#b
if (abs(a-e) == 1 or abs(b-f) == 1) & (abs(e-c) != abs(f-d)):
    print('Yes')
else: print('No')

#c
if (abs(a-e) == 1 or abs(b-f) == 1) & (abs(e-c) != abs(f-d)) & (e != c) & (f != d):
    print('Yes')
else: print('No')
# Out:
# a:2
# b:3
# c:3
# d:6
# e:3
# f:4
# No
# Yes
# No

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for x in range(11):
    for y in range(21):
        z = 100 - x - y
        if z >= 0 and (10 * x + 5 * y + 0.5 * z) == 100:
            print(f"быков: {x}, коров: {y}, телят: {z}")
# Out:
# быков: 1, коров: 9, телят: 90

# %%
from math import sin
n = int(input('n:'))
x = float(input('x:'))
summ = 0
current = x
for i in range(n):
  current = sin(sin(current))
  summ += current
print(f'result = {summ}')
# Out:
# n:3
# x:3.14
# result = 0.004777952689722698

# %%
from math import factorial
summ = 0
E = 0.001
i = 0
while True:
  t = factorial(i)/factorial(2*i)
  if t < E: break
  summ += t
  i+=1
print(f'summ = {summ}')
# Out:
# summ = 1.5916666666666666

# %%
N = int(input('N:'))
arr = list(map(int, input("In numbers: ").split()))
if N != len(arr):
  print('Error')
else:
  K = 0
  for i in range(N-1):
    if(arr[i] < arr[i+1]):
      K += 1
      print(arr[i])
print(f'K: {K}')
# Out:
# N:5
# In numbers: 1 2 5 4 6
# 1
# 2
# 4
# K: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def dig_sum(a):
  s = 0
  while a > 0:
    s += a%10
    a = a//10
  return s

a = int(input('a: '))
count = 0
while a > 0:
  a -= dig_sum(a)
  count += 1
print(f'iterations: {count}') # a//9 + 1 итераций
# Out:
# a: 53
# iterations: 6

# %%
arr = list(map(int, input("In numbers: ").split()))
count = 0
for i in range(len(arr)):
  if arr[i] < 0:
    arr[i] *= -1
    count +=1
print(*arr)
print(f'replaces: {count}')
# Out:
# In numbers: 5 -2 45 -111 3 -2 -3
# 5 2 45 111 3 2 3
# replaces: 4

# %%
from math import factorial
n = int(input('n: '))
while n%2 != 1 or n >20:
  n = int(input('enter an even n: '))
summ = 0
while n > 0:
  summ += factorial(n)
  n -= 2
print(f'result = {summ}')
# Out:
# n: 3
# result = 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import randint
a = []
n = int(input('n: '))
min = 1000
ind = 1
for i in range(2*n):
  a.append(randint(-100, 100))
  if a[i] < min:
    min = a[i]
    ind = i
print(*a)
a[1], a[ind] = a[ind], a[1]
print(*a)
# Out:
# n: 3
# -90 51 -57 85 -33 -46
# 51 -90 -57 85 -33 -46

# %%
from random import randint
a = []
n = int(input('n: '))
max = -101
max0 = max
for i in range(n):
  a.append(randint(-100, 100))
for i in range(1, n-1):
   if (a[i-1] < a[i] & a[i] > a[i+1]) or (a[i-1] > a[i] & a[i] < a[i+1]): continue
   if (a[i] > max):max=a[i]
if not(a[0] > a[1] or a[0] < a[1]) & a[0] > max: max = a[0]
if not(a[-1] > a[-2] or a[-1] < a[-2]) & a[-1] > max: max = a[-1]
print(*a)
if(max == max0): print('0')
else: print(f'max: {max}')
# Out:
# n: 9
# 26 27 48 -80 -20 63 60 7 25
# max: 25

# %%
from random import randint
a = []
n = int(input('n: '))
for i in range(n):
  a.append(randint(-100, 100))
print(*a)
k = 0
for i in range(n):
  if a[k] % 2 == 1:
      a.pop(k)
  else: k += 1
print(*a)
# Out:
# n: 6
# 99 40 32 75 1 36
# 40 32 36

# %%
from random import randint
a = []
n = int(input('n: '))
m = int(input('m: '))
k = int(input('k: '))
for i in range(n):
  x = []
  for j in range(m):
    x.append(randint(-100,100))
  a.append(x)
for i in range(n):
  print(a[i])
res = []
for i in range(n):
  for j in range(m):
    if(a[i][j] % m == k): res.append(a[i][j])
print(*res)
# Out:
# n: 3
# m: 4
# k: 2
# [-49, -53, 36, -51]
# [40, 32, 6, 69]
# [29, -7, 46, 3]
# 6 46

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
str = input('string: ')
s = 0
number = ''
flag = False
for i in str:
  if i.isdigit():
    number += i
    flag = True
  elif flag:
    s += int(number)
    flag = False
    number = ''
if flag: s += int(number)
print(f'summ = {s}')
# Out:
# string: 34dfgkn34kkls k4
# summ = 72

# %%
str = input('string: ')
result = ''
for i in str:
  if i == ' ': result += ', '
  else: result += i
print(result)
# Out:
# string: kdfg kmk  wek3
# kdfg, kmk, , wek3,

# %%
str = input('string: ')
count = 0
str = str.split('.')[0]
words = str.split(',')
for i in words:
  if i[0] == i[-1]: count += 1
print(f'count = {count}')
# Out:
# string: djksg,fssdf, da,nen,dfe.faf
# count = 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
with open("file.txt", "r") as file:
    str = file.read()

new_str = str.split(" ", 1)[-1]

with open("file.txt", "w") as file:
    file.write(new_str)

# %%
FILENAME = "numbers.txt"
numbers = []
with open(FILENAME, "r") as file:
    for line in file:
        numbers.extend(map(int, line.split()))
N = len(numbers)
res = []

for i in range((N + 1) // 2):
    res.append(numbers[i])
    if N - 1 - i > i:
        res.append(numbers[N - 1 - i])

with open(FILENAME, "w") as file:
    for num in res:
        file.write(str(num) + " ")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

def SwapRow(A,M,N,K1,K2):
  if(K1 > M or K2 > M): return A
  A[K1],A[K2] = A[K2],A[K1]
  return A

a = []
m = int(input('m: '))
n = int(input('n: '))
for i in range(m):
  x = []
  for j in range(n):
    x.append(random.uniform(-100, 100))
  a.append(x)
  print(*x)
k1 = int(input('k1: '))
k2 = int(input('k2: '))
a = SwapRow(a,m,n,k1,k2)
for i in a:
  print(*i)
# Out:
# m: 3
# n: 4
# 76.73004455474924 88.91658369809466 1.631701590695215 64.987507441785
# -97.1071587006084 -52.39975321132586 -80.30069605622981 90.62282689629782
# -96.69418856446018 24.581734661371215 85.92505616236741 -84.64634213455899
# k1: 0
# k2: 2
# -96.69418856446018 24.581734661371215 85.92505616236741 -84.64634213455899
# -97.1071587006084 -52.39975321132586 -80.30069605622981 90.62282689629782
# 76.73004455474924 88.91658369809466 1.631701590695215 64.987507441785
