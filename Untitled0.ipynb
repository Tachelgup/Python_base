# %% [markdown]
# <a href="https://colab.research.google.com/github/Tachelgup/Python_base/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())
b = int(input())
c = int(input())
y = (a*(a-b)+2*a*b)/((a+b)*c)
print(y)
# Out:
# 2
# 3
# 4
# 0.5

# %%
from math import log, pow
x = int(input())
z = x*pow(log(x),2)+x/(log(x)-1)
print(z)
# Out:
# 1
# -1.0

# %%
from math import pow, pi
r = int(input())
l = 2*pi*r
s = pi*pow(r,2)
print(" l: ", l ,'\n','s: ', s)
# Out:
# 1
#  l:  6.283185307179586
#  s:  3.141592653589793
